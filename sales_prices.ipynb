# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Train.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
len(df[df.columns[0]].unique())
# Out:
# 1559

# %%
df1=df.copy()

# %%
df1.drop("Item_Identifier",inplace=True,axis=1)

# %%
df1.head()
# Out:
#    Item_Weight Item_Fat_Content  ...        Outlet_Type Item_Outlet_Sales
# 0         9.30          Low Fat  ...  Supermarket Type1         3735.1380
# 1         5.92          Regular  ...  Supermarket Type2          443.4228
# 2        17.50          Low Fat  ...  Supermarket Type1         2097.2700
# 3        19.20          Regular  ...      Grocery Store          732.3800
# 4         8.93          Low Fat  ...  Supermarket Type1          994.7052
#
# [5 rows x 11 columns]

# %%
df1.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df1["Outlet_Establishment_Year"]=df1["Outlet_Establishment_Year"].apply(lambda x:2021-x)
df1["Outlet_Establishment_Year"].head()
# Out:
# 0    22
# 1    12
# 2    22
# 3    23
# 4    34
# Name: Outlet_Establishment_Year, dtype: int64

# %%
for i in [0,2,4,10]:
  plt.figure(figsize=(15,8))
  ax = sns.histplot(df1[df1.columns[i]], color='0.8', kde=True,bins=27)
  ax.lines[0].set_color('brown')

# %%
for i in [1,3,5,7,8,9]:
  if i==3:
    plt.figure(figsize=(15,6))
    sns.countplot(x=df1[df1.columns[i]])
    plt.xticks(rotation=75)
    plt.show()
  else:
    plt.figure(figsize=(8,6))
    sns.countplot(x=df1[df1.columns[i]])
    plt.xticks(rotation=75)
    plt.show()

# %%
df1.Outlet_Identifier.value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT035    930
# OUT046    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df2=df1.copy()

# %%
df2.dtypes
# Out:
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
from scipy import stats

# %%
sc=StandardScaler()
le=LabelEncoder()

# %%
df2=df1.copy()

# %%
media=np.median(df2[df2.columns[0]].dropna()) #median does not support nan values
print(media)
# Out:
# 12.6

# %%
class preprocess:
  
  def nan_check(self,cols):
    for i in cols:
      if df2.dtypes[i]=="float64" or df2.dtypes[i]=="int64":
        df2[df2.columns[i]].fillna(value=media,inplace=True)
      
      if  df2.dtypes[i]=="object":
        df2[df2.columns[i]].fillna(stats.mode(df2[df2.columns[i]])[0][0],inplace=True)
    return df2
      
  def numeric(self,cols):
    for i in cols:
      df2[[df2.columns[i]]]=sc.fit_transform(df2[[df2.columns[i]]])
    return df2
  
  def obj(self,cols):
    for i in cols:
      df2[[df2.columns[i]]]=le.fit_transform(df2[df2.columns[i]])
    return df2

# %%
ob=preprocess() #object of the class

# %%
ob.nan_check([0,7]).isna().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
ob.numeric([0,2,4,6]).head()
# Out:
#    Item_Weight Item_Fat_Content  ...        Outlet_Type Item_Outlet_Sales
# 0    -0.831187          Low Fat  ...  Supermarket Type1         3735.1380
# 1    -1.630810          Regular  ...  Supermarket Type2          443.4228
# 2     1.108727          Low Fat  ...  Supermarket Type1         2097.2700
# 3     1.510904          Regular  ...      Grocery Store          732.3800
# 4    -0.918719          Low Fat  ...  Supermarket Type1          994.7052
#
# [5 rows x 11 columns]

# %%
ob.obj([1,3,5,7,8,9]).head()
# Out:
#    Item_Weight  Item_Fat_Content  ...  Outlet_Type  Item_Outlet_Sales
# 0    -0.831187                 1  ...            1          3735.1380
# 1    -1.630810                 2  ...            2           443.4228
# 2     1.108727                 1  ...            1          2097.2700
# 3     1.510904                 2  ...            0           732.3800
# 4    -0.918719                 1  ...            1           994.7052
#
# [5 rows x 11 columns]

# %%
df2.head()
# Out:
#    Item_Weight  Item_Fat_Content  ...  Outlet_Type  Item_Outlet_Sales
# 0    -0.831187                 1  ...            1          3735.1380
# 1    -1.630810                 2  ...            2           443.4228
# 2     1.108727                 1  ...            1          2097.2700
# 3     1.510904                 2  ...            0           732.3800
# 4    -0.918719                 1  ...            1           994.7052
#
# [5 rows x 11 columns]

# %%
df2["Item_Type"].unique()
# Out:
# array([ 4, 14, 10,  6,  9,  0, 13,  5,  2,  8,  7,  3,  1, 15, 11, 12])

# %%
df2.to_csv("preprocessed.csv",index=False) #this file can be used directly to train ML models without preprocessing

# %%
df3=df2.copy()

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df3.corr(),annot=True,cmap="icefire")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df3.drop("Item_Outlet_Sales",inplace=True,axis=1)

# %%
x=df3
y=df2["Item_Outlet_Sales"]

# %%
x.head()
# Out:
#    Item_Weight  Item_Fat_Content  ...  Outlet_Location_Type  Outlet_Type
# 0    -0.831187                 1  ...                     0            1
# 1    -1.630810                 2  ...                     2            2
# 2     1.108727                 1  ...                     0            1
# 3     1.510904                 2  ...                     2            0
# 4    -0.918719                 1  ...                     2            1
#
# [5 rows x 10 columns]

# %%
y.head()
# Out:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
def models(name):
  st=str(name)
  name.fit(x_train,y_train)
  y_pred=name.predict(x_test)
  mae=mean_absolute_error(y_pred,y_test)
  print(mae,"is the mean absolute error for",st.split("(")[0],"\n")
  print("-------------------------------------------------------")

# %%
lr=LinearRegression()
rfr=RandomForestRegressor()
ext=ExtraTreesRegressor()

# %%
models(lr)
models(rfr)
models(ext)
# Out:
# 855.2107779174092 is the mean absolute error for LinearRegression
#
# -------------------------------------------------------
# 756.9800174498533 is the mean absolute error for RandomForestRegressor
#
# -------------------------------------------------------
# 773.4241410991201 is the mean absolute error for ExtraTreesRegressor
#
# -------------------------------------------------------
